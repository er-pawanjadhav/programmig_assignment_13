# %%
a =  input("enter numbers : ")
a = a.split(",")
d ,c,h,q = [],50,30,[]
c = c/h
for i in a:
    if len(i)!=0:
        i = int(i)
        d.append(i)

for i in range(len(d)):
    r = 2*c*d[i]
    r = round(r**0.5)
    q.append(r)
    continue
print(q)
