# %%
import re
n = input("enter passwords")
n = n.split(",")

def check(a):
    patt1 = '[a-z]'
    patt2 = '[A-Z]'
    patt3 = '[0-9]'
    patt4 = '[$#@]'
    b = f"{a} is not a valid password"
    r1 = re.search(patt1,a)
    r2 = re.search(patt2,a)
    r3 = re.search(patt3,a)
    r4 = re.search(patt4,a)
    if len(a)>=6 and len(a)<=12:
        if r1:
            if r2:
                if r3:
                    if r4:
                        return 1
                    else:
                        return 0
                else:
                    return 0
            else:
                return 0
        else:
            return 0
    else:
        return 0

for i in n:
    a = check(i)
    if a :
        print(i)
    else:
        pass
