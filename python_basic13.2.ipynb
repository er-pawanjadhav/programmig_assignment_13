# %%
r = int(input("Input number of row : "))
c = int(input("Input number of columns : "))
l= [[0 for col in range(c)] for i in range(r)]

for i in range(r):
    for j in range(c):
        l[i][j]= i*j

print(l)
# Out:
# Input number of row : 3
# Input number of columns : 5
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]
